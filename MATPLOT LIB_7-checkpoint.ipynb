# %%
import matplotlib

# %%
import matplotlib.pyplot as plt

# %%
import numpy as np

# %%
xpoint=np.array([0,5])
ypoint=np.array([0,200])
plt.plot(xpoint,ypoint)

# %%
xpoint=np.array([0,5,3,51,7])
ypoint=np.array([0,200,105,110,300])
plt.plot(xpoint,ypoint)

# %%
xpoint=np.array([0,5,3,51,7])
ypoint=np.array([0,200,105,110,300])
plt.plot(xpoint,ypoint,marker='o')

# %%
xpoint=np.array([0,5,3,51,7])
ypoint=np.array([0,200,105,110,300])
plt.plot(xpoint,ypoint,marker='*')

# %%
xpoint=np.array([0,5,3,51,7])
ypoint=np.array([0,200,105,110,300])
plt.plot(xpoint,ypoint,marker='+')

# %%
xpoint=np.array([0,5,3,51,7])
ypoint=np.array([0,200,105,110,300])
plt.plot(xpoint,ypoint,marker='*',ms=10)

# %%
xpoint=np.array([0,5,3,51,7])
ypoint=np.array([0,200,105,110,300])
plt.plot(xpoint,ypoint,marker='*',ms=10,mec='r')

# %%
xpoint=np.array([0,5,3,51,7])
ypoint=np.array([0,200,105,110,300])
plt.plot(xpoint,ypoint,marker='*',ms=10,mec='black')

# %%
o-circle,*,.,+s,D,d,p-pentagon,H-Hexagon,v-Triangle down ,<,>,

# %%
xpoint=np.array([0,5,3,51,7])
ypoint=np.array([0,200,105,110,300])
plt.plot(xpoint,ypoint,marker='*',ms=10,mfc='r',mec='b')

# %%
xpoint=np.array([0,5,3,51,7])
ypoint=np.array([0,200,105,110,300])
plt.plot(xpoint,ypoint,marker='*',ms=10,mfc='r',mec='k')

# %%
r-red, g-green, b-blue, c-cyan, m-magenta, y-yellow, k-black, w-white

# %%
xpoint=np.array([0,5,3,51,7])
ypoint=np.array([0,200,105,110,300])
plt.plot(xpoint,ypoint,marker='*',ms=10,mfc='r',mec='r',ls='dotted')

# %%
xpoint=np.array([0,5,3,51,7])
ypoint=np.array([0,200,105,110,300])
plt.plot(xpoint,ypoint,marker='*',ms=10,mfc='m',mec='r',ls='dotted',color='r')

# %%
xpoint=np.array([0,5,3,51,7])
ypoint=np.array([0,200,105,110,300])
plt.plot(xpoint,ypoint,marker='*',ms=10,mec='r',ls='dotted',color='r')

# %%
xpoint=np.array([0,5,3,51,7])
ypoint=np.array([0,200,105,110,300])
plt.plot(xpoint,ypoint,marker='*',ms=10,mec='r',ls='--',color='r')

# %%
xpoint=np.array([0,5,3,51,7])
ypoint=np.array([0,200,105,110,300])
plt.plot(xpoint,ypoint,marker='*',ms=10,mec='r',ls='solid',color='r')

# %%
xpoint=np.array([0,5,3,51,7])
ypoint=np.array([0,200,105,110,300])
plt.plot(xpoint,ypoint,marker='*',ms=10,mec='r',ls='solid',color='r')
plt.xlabel("x data")
plt.ylabel("y data")
# Out:
# Text(0, 0.5, 'y data')

# %%
xpoint=np.array([0,5,3,51,7])
ypoint=np.array([0,200,105,110,300])
plt.plot(xpoint,ypoint,marker='*',ms=10,mec='r',ls='-.',color='r')
plt.xlabel("x data")
plt.ylabel("y data")
plt.title ('x & y data')
# Out:
# Text(0.5, 1.0, 'x & y data')

# %%
xpoint=np.array([0,5,3,51,7])
ypoint=np.array([0,200,105,110,300])
plt.plot(xpoint,ypoint,marker='*',ms=10,mec='r',ls='-.',color='r')
plt.xlabel("x data")
plt.ylabel("y data")
plt.title ('x & y data')
plt.grid(axis='y')

# %%
xpoint=np.array([0,5,3,51,7])
ypoint=np.array([0,200,105,110,300])
plt.plot(xpoint,ypoint,marker='*',ms=10,mec='r',ls='-.',color='r')
plt.xlabel("x data")
plt.ylabel("y data")
plt.title ('x & y data')
plt.grid(axis='y',color='g')

# %%
x=np.array([1,2,3,4])
y=np.array([3,4,5,6])
plt.subplot(2,1,1)
plt.plot(x,y)
x=np.array([11,22,33,44])
y=np.array([34,44,54,64])
plt.subplot(2,1,2)
plt.plot(x,y)

# %%
x=np.array([1,2,3,4])
y=np.array([3,4,5,6])
plt.subplot(1,2,1)
plt.plot(x,y)
x=np.array([11,22,33,44])
y=np.array([34,44,54,64])
plt.subplot(1,2,2)
plt.plot(x,y)

# %%
x=np.array([1,2,3,4])
y=np.array([3,4,5,6])
plt.scatter(x,y)

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,4,5,6])
plt.bar(x,y)
# Out:
# <BarContainer object of 4 artists>

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,4,5,6])
plt.bar(x,y,color='r')
# Out:
# <BarContainer object of 4 artists>

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,4,5,6])
plt.bar(x,y,color='r',width=0.5)
# Out:
# <BarContainer object of 4 artists>

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,4,5,6])
plt.barh(x,y,color='g',height=0.5)
# Out:
# <BarContainer object of 4 artists>

# %%
x=np.array(["A","B","C","D"])
y=np.array([3,4,5,6])
plt.barh(x,y,color='g',height=0.5)
# Out:
# <BarContainer object of 4 artists>

# %%
x=np.array([35,25,25,15])
plt.pie(x)
plt.show()

# %%
x=np.array([35,25,25,15])
mylabels=["Car","Bike","Truck","Bus"]
plt.pie(x,labels=mylabels)
plt.show()

# %%
x=np.array([35,25,25,15])
mylabels=["Car","Bike","Truck","Bus"]
myexplode=[0.1,0,0,0]
plt.pie(x,labels=mylabels,explode=myexplode)
plt.show()

# %%
x=np.array([35,25,25,15])
mylabels=["Car","Bike","Truck","Bus"]
myexplode=[0.1,0,0,0]
mycolor=["black","hotpink","b","magenta"]
plt.pie(x,labels=mylabels,explode=myexplode,colors=mycolor)
plt.show()

# %%
x=np.array([35,25,25,15])
mylabels=["Car","Bike","Truck","Bus"]
myexplode=[0.1,0,0,0]
mycolor=["black","hotpink","b","magenta"]
plt.pie(x,labels=mylabels,explode=myexplode,colors=mycolor)
plt.legend()
plt.show()

# %%
import pandas as pd
df=pd.read_csv("iris.csv")

# %%
df
# Out:
#       Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm  \
# 0      1            5.1           3.5            1.4           0.2
# 1      2            4.9           3.0            1.4           0.2
# 2      3            4.7           3.2            1.3           0.2
# 3      4            4.6           3.1            1.5           0.2
# 4      5            5.0           3.6            1.4           0.2
# ..   ...            ...           ...            ...           ...
# 145  146            6.7           3.0            5.2           2.3
# 146  147            6.3           2.5            5.0           1.9
# 147  148            6.5           3.0            5.2           2.0
# 148  149            6.2           3.4            5.4           2.3
# 149  150            5.9           3.0            5.1           1.8
#
#             Species
# 0       Iris-setosa
# 1       Iris-setosa
# 2       Iris-setosa
# 3       Iris-setosa
# 4       Iris-setosa
# ..              ...
# ...

# %%
df.plot(x="SepalLengthCm",y="PetalLengthCm",kind="scatter")
# Out:
# <Axes: xlabel='SepalLengthCm', ylabel='PetalLengthCm'>
