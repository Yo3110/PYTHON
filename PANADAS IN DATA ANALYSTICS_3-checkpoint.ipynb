# %% [markdown]
# ## PANADAS IN DATA ANALYSTICS

# %%
import pandas as pd

# %%
print(pd.__version__)
# Out:
# 1.5.3

# %%
data=[2,3,4,6,5]
series=pd.Series(data)

# %%
series
# Out:
# 0    2
# 1    3
# 2    4
# 3    6
# 4    5
# dtype: int64

# %%
data=[2,3,4,6,5],[3,4,5,6,7]
series=pd.Series(data)

# %%
series
# Out:
# 0    [2, 3, 4, 6, 5]
# 1    [3, 4, 5, 6, 7]
# dtype: object

# %%
data=[2,3,4,6,5],[3,4,5,6,7]
df=pd.DataFrame(data)

# %%
df
# Out:
#    0  1  2  3  4
# 0  2  3  4  6  5
# 1  3  4  5  6  7

# %%
dict={"name":["ss",'ram','shyam','hari','som'],"loc":['benglore', 'chennai','mumbai','delhi','pune']}

# %%
pd.DataFrame(dict)
# Out:
#     name       loc
# 0     ss  benglore
# 1    ram   chennai
# 2  shyam    mumbai
# 3   hari     delhi
# 4    som      pune

# %%
df=pd.DataFrame({"name":["ss",'ram','shyam','hari','som'],"loc":['benglore', 'chennai','mumbai','delhi','pune']})

# %%
df
# Out:
#     name       loc
# 0     ss  benglore
# 1    ram   chennai
# 2  shyam    mumbai
# 3   hari     delhi
# 4    som      pune

# %%
df.to_csv("data.csv")

# %%
df
# Out:
#     name       loc
# 0     ss  benglore
# 1    ram   chennai
# 2  shyam    mumbai
# 3   hari     delhi
# 4    som      pune

# %%
df.to_csv("data.csv",index=False)

# %%
df
# Out:
#     name       loc
# 0     ss  benglore
# 1    ram   chennai
# 2  shyam    mumbai
# 3   hari     delhi
# 4    som      pune

# %%
df=pd.read_csv("data2.csv")

# %%
df=pd.read_excel("c:/Users/dell/Dekstop")

# %%
1. rename the file to sales_sept_2023
2.load the file to the enviorment

# %%
df=pd.read_csv("C:/Users/yoges/OneDrive/Desktop/sales_sept_2023.csv")

# %%
df
# Out:
#       Order ID                     Product Quantity Ordered Price Each  \
# 0       176558        USB-C Charging Cable                2      11.95
# 1          NaN                         NaN              NaN        NaN
# 2       176559  Bose SoundSport Headphones                1      99.99
# 3       176560                Google Phone                1        600
# 4       176560            Wired Headphones                1      11.99
# ...        ...                         ...              ...        ...
# 18378   194090                Google Phone                1        600
# 18379   194091       AA Batteries (4-pack)                1       3.84
# 18380   194092      AAA Batteries (4-pack)                2       2.99
# 18381   194093       AA Batteries (4-pack)                1       3.84
# 18382   194094    Lightning Charging Cable                1      14.95
#
#            Order Date                        Purchase Address
# ...

# %%
df[['Order ID','Product', 'Quantity Ordered']][11:30]
# Out:
#    Order ID                     Product Quantity Ordered
# 11   176567                Google Phone                1
# 12   176568    Lightning Charging Cable                1
# 13   176569      27in 4K Gaming Monitor                1
# 14   176570       AA Batteries (4-pack)                1
# 15   176571    Lightning Charging Cable                1
# 16   176572    Apple Airpods Headphones                1
# 17   176573        USB-C Charging Cable                1
# 18   176574                Google Phone                1
# 19   176574        USB-C Charging Cable                1
# 20   176575      AAA Batteries (4-pack)                1
# 21   176576    Apple Airpods Headphones                1
# 22   176577    Apple Airpods Headphones                1
# 23   176578    Apple Airpods Headphones                1
# 24   176579       AA Batteries (4-pack)                1
# 25   176580        USB-C Charging Cable                1
# ...

# %%
data=df[['Order ID','Product', 'Quantity Ordered']][11:30]

# %%
data
# Out:
#    Order ID                     Product Quantity Ordered
# 11   176567                Google Phone                1
# 12   176568    Lightning Charging Cable                1
# 13   176569      27in 4K Gaming Monitor                1
# 14   176570       AA Batteries (4-pack)                1
# 15   176571    Lightning Charging Cable                1
# 16   176572    Apple Airpods Headphones                1
# 17   176573        USB-C Charging Cable                1
# 18   176574                Google Phone                1
# 19   176574        USB-C Charging Cable                1
# 20   176575      AAA Batteries (4-pack)                1
# 21   176576    Apple Airpods Headphones                1
# 22   176577    Apple Airpods Headphones                1
# 23   176578    Apple Airpods Headphones                1
# 24   176579       AA Batteries (4-pack)                1
# 25   176580        USB-C Charging Cable                1
# ...

# %%
df["Product"].unique()
# Out:
# array(['USB-C Charging Cable', nan, 'Bose SoundSport Headphones',
#        'Google Phone', 'Wired Headphones', 'Macbook Pro Laptop',
#        'Lightning Charging Cable', '27in 4K Gaming Monitor',
#        'AA Batteries (4-pack)', 'Apple Airpods Headphones',
#        'AAA Batteries (4-pack)', 'iPhone', 'Flatscreen TV',
#        '27in FHD Monitor', '20in Monitor', 'LG Dryer', 'ThinkPad Laptop',
#        'Vareebadd Phone', 'LG Washing Machine', '34in Ultrawide Monitor',
#        'Product'], dtype=object)

# %% [markdown]
# ## Null Values

# %%
df.isnull()
# Out:
#        Order ID  Product  Quantity Ordered  Price Each  Order Date  \
# 0         False    False             False       False       False
# 1          True     True              True        True        True
# 2         False    False             False       False       False
# 3         False    False             False       False       False
# 4         False    False             False       False       False
# ...         ...      ...               ...         ...         ...
# 18378     False    False             False       False       False
# 18379     False    False             False       False       False
# 18380     False    False             False       False       False
# 18381     False    False             False       False       False
# 18382     False    False             False       False       False
#
#        Purchase Address
# 0                 False
# 1                  True
# 2                 False
# 3                 False
# 4                 False
# ...

# %%
df.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1      NaN                         NaN              NaN        NaN
# 2   176559  Bose SoundSport Headphones                1      99.99
# 3   176560                Google Phone                1        600
# 4   176560            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1             NaN                                   NaN
# 2  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001

# %%
df['Order ID'].isnull()
# Out:
# 0        False
# 1         True
# 2        False
# 3        False
# 4        False
#          ...
# 18378    False
# 18379    False
# 18380    False
# 18381    False
# 18382    False
# Name: Order ID, Length: 18383, dtype: bool

# %%
df.isnull().sum()
# Out:
# Order ID            59
# Product             59
# Quantity Ordered    59
# Price Each          59
# Order Date          59
# Purchase Address    59
# dtype: int64
